# %% [markdown]
# # Twitter Scrape Results Analysis
#
# This notebook focuses on alayzing the data collected from Twitter by the WebScraper in this repository, and answering the practical test.

# %% [markdown]
# # Index
#
# [Imports](#Imports)
#
# [Reading and Organizing Data](#Reading-and-Organizing-Data)
#
# [Minimal Requirements](#Minimal-Requirements)
#
# [Results](#Results)
#
# [Free EDA](#Free-EDA)
#
# [Conclusion](#Conclusion)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import pickle
import os
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %% [markdown]
# # Reading and Organizing Data
#
# We will read the pickle files which contain dictionaries of user data, including the 10 tweets. Then we will create a dataframe with the data inside the dictionaries

# %% [markdown]
# Listing all the pickle file in the Output directory, where the scraper leaves the data.

# %%
pkl_dicts = glob('Output\\*.pkl')
assert len(pkl_dicts)>0

# %% [markdown]
# Iterating through file paths, reading the dictionaries, and appending them to a list called dicts

# %%
dicts=[]
for dictionary in pkl_dicts:
    with open(dictionary, 'rb') as pkl2dict:
        dicts.append(pickle.load(pkl2dict))

#Showing a sample
print(dicts[0])
# Out:
# {'user_name': 'alanzoka', 'displayed_name': 'Alan Ferreira', 'followers': 3100000.0, 'following': 574.0, 'birthday': None, 'date_joined': datetime.datetime(2009, 7, 1, 0, 0), 'profile_description': 'to sempre jogando alguma coisa ai. ', 'website': 'youtube.com/alanzoka', 'posts_data': {'1559648553714196480': {'date': datetime.datetime(2022, 8, 16, 21, 9, 26, tzinfo=datetime.timezone.utc), 'likes': 4.198, 'replies': 56.0, 'retweets': 44.0}, '1559610243276996609': {'date': datetime.datetime(2022, 8, 16, 18, 37, 12, tzinfo=datetime.timezone.utc), 'likes': 4.453, 'replies': 74.0, 'retweets': 45.0}, '1558159295245582336': {'date': datetime.datetime(2022, 8, 12, 18, 31, 39, tzinfo=datetime.timezone.utc), 'likes': 1.782, 'replies': 35.0, 'retweets': 108.0}, '1557788407472046082': {'date': datetime.datetime(2022, 8, 11, 17, 57, 53, tzinfo=datetime.timezone.utc), 'likes': 1.477, 'replies': 13.0, 'retweets': 46.0}, '1557543326718607360': {'date': datetime.datetime(2022, 8, 11, 1, 44, 1, tzinfo=datetime.timezone.utc), 'likes': 3.999, 'replies': 37.0, 'retweets': 37.0}, '1557434376941699080': {'date': datetime.datetime(2022, 8, 10, 18, 31, 5, tzinfo=datetime.timezone.utc), 'likes': 1.466, 'replies': 19.0, 'retweets': 52.0}, '1555742094542635008': {'date': datetime.datetime(2022, 8, 6, 2, 26, 34, tzinfo=datetime.timezone.utc), 'likes': 4.037, 'replies': 41.0, 'retweets': 45.0}, '1555623403213692928': {'date': datetime.datetime(2022, 8, 5, 18, 34, 56, tzinfo=datetime.timezone.utc), 'likes': 1.754, 'replies': 21.0, 'retweets': 95.0}, '1554900932181336064': {'date': datetime.datetime(2022, 8, 3, 18, 44, 5, tzinfo=datetime.timezone.utc), 'likes': 1.703, 'replies': 50.0, 'retweets': 112.0}, '1546682651507150848': {'date': datetime.datetime(2022, 7, 12, 2, 27, 34, tzinfo=datetime.timezone.utc), 'likes': 11900.0, 'replies': 229.0, 'retweets': 212.0}}}

# %% [markdown]
# Now we iterate through the dictionaries, get the username of each profile, read the CSV files with the tweets data for that user (because it is easier) and create a big dataframe with all the posts and their respective users. We will also get the date each user joined and the number of followers for later

# %%
main_df = pd.DataFrame()
for dictionary in dicts:
    user = dictionary.get('user_name')
    posts_dataframe = pd.read_csv(f'Output\\{user}.csv', index_col=0)
    posts_dataframe['user'] = user
    posts_dataframe['date_joined'] =  dictionary.get('date_joined')
    posts_dataframe['followers'] =  dictionary.get('followers')
    
    if main_df.empty:
        main_df = posts_dataframe
    else:
        main_df = pd.concat([main_df, posts_dataframe])

main_df.head()
# Out:
#                                           date  likes  replies  retweets  \
# 1559648553714196480  2022-08-16 21:09:26+00:00  4.198     56.0      44.0
# 1559610243276996609  2022-08-16 18:37:12+00:00  4.453     74.0      45.0
# 1558159295245582336  2022-08-12 18:31:39+00:00  1.782     35.0     108.0
# 1557788407472046082  2022-08-11 17:57:53+00:00  1.477     13.0      46.0
# 1557543326718607360  2022-08-11 01:44:01+00:00  3.999     37.0      37.0
#
#                          user date_joined  followers
# 1559648553714196480  alanzoka  2009-07-01  3100000.0
# 1559610243276996609  alanzoka  2009-07-01  3100000.0
# 1558159295245582336  alanzoka  2009-07-01  3100000.0
# 1557788407472046082  alanzoka  2009-07-01  3100000.0
# 1557543326718607360  alanzoka  2009-07-01  3100000.0

# %% [markdown]
# # Minimal Requirements
#
# Here is the data that was asked that the analysis must have

# %% [markdown]
# Let us check our date column to see if its a datetime object still or a string

# %%
np.unique([str(type(c)) for c in main_df['date']])
# Out:
# array(["<class 'str'>"], dtype='<U13')

# %% [markdown]
# Now let us change that

# %%
main_df['date'] = [dt.datetime.fromisoformat(c) for c in main_df['date']]

# %% [markdown]
# Add some columns that will help us get the information we need

# %%
main_df['day'] = [c.day for c in main_df.date]
main_df['month'] = [c.month for c in main_df.date]
main_df['week_of_year'] = [c.isocalendar().week for c in main_df.date]

# %%
main_df.head()
# Out:
#                                          date  likes  replies  retweets  \
# 1559648553714196480 2022-08-16 21:09:26+00:00  4.198     56.0      44.0
# 1559610243276996609 2022-08-16 18:37:12+00:00  4.453     74.0      45.0
# 1558159295245582336 2022-08-12 18:31:39+00:00  1.782     35.0     108.0
# 1557788407472046082 2022-08-11 17:57:53+00:00  1.477     13.0      46.0
# 1557543326718607360 2022-08-11 01:44:01+00:00  3.999     37.0      37.0
#
#                          user date_joined  followers  day  month  week_of_year
# 1559648553714196480  alanzoka  2009-07-01  3100000.0   16      8            33
# 1559610243276996609  alanzoka  2009-07-01  3100000.0   16      8            33
# 1558159295245582336  alanzoka  2009-07-01  3100000.0   12      8            32
# 1557788407472046082  alanzoka  2009-07-01  3100000.0   11      8            32
# 1557543326718607360  alanzoka  2009-07-01  3100000.0   11      8            32

# %% [markdown]
# ## Important Note
#
# Since we are collecting data on the first 10 posts of a user profile, this data will be heavily skewed towards the date in which the data was collected (17/08/2022). So this analysis of tweets per day and so on, is not so reliable unless we reduce the scope of our dataframe, to maybe, only data in August of 2022. But we won't do that for now.
#
# Below we can check the skew of the Days, Months and Weeks of year of our dataframe.

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['month'], kde=False)
fig.suptitle('Months Distribution', fontsize=20)
plt.xlabel('Months', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# D:\Users\iuryck\anaconda3\envs\AnalyzeData\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['day'], kde=False)
fig.suptitle('Day of Month Distribution', fontsize=20)
plt.xlabel('Day', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['week_of_year'], kde=False)
fig.suptitle('Week of the Year', fontsize=20)
plt.xlabel('Week of the Year', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Now we will be using GroupBy and our data columns we have created to easily get the tweets per day, month and week

# %%
tweets_pday = main_df[['day','user']].groupby('day').count()
tweets_pday = tweets_pday.rename(columns={'user':'tweets'})


tweets_pweek = main_df[['week_of_year','user']].groupby('week_of_year').count()
tweets_pweek = tweets_pweek.rename(columns={'user':'tweets'})

tweets_pmonth = main_df[['month','user']].groupby('month').count()
tweets_pmonth = tweets_pmonth.rename(columns={'user':'tweets'})

# %% [markdown]
# ## Results

# %%
print(f'Mean tweets per day: { tweets_pday["tweets"].mean() }')
print(f'Median tweets per day: { tweets_pday["tweets"].median() }')
tweets_pday
# Out:
# Mean tweets per day: 52.25806451612903
# Median tweets per day: 29.0
#      tweets
# day
# 1        17
# 2        27
# 3        25
# 4        29
# 5        38
# 6        29
# 7        31
# 8        37
# 9        35
# 10       59
# 11       62
# 12       66
# 13       65
# 14      105
# 15      111
# 16      253
# 17      235
# 18      149
# 19       11
# 20        9
# 21       18
# 22       19
# 23       16
# 24       24
# 25       19
# 26       31
# 27       15
# 28       26
# 29       36
# 30       15
# 31        8

# %%
print(f'Mean tweets per week: { tweets_pweek["tweets"].mean() }')
print(f'Median tweets per week: { tweets_pweek["tweets"].median() }')
tweets_pweek
# Out:
# Mean tweets per week: 36.81818181818182
# Median tweets per week: 6.5
#               tweets
# week_of_year
# 1                  1
# 2                  2
# 3                  8
# 4                  6
# 5                  4
# 6                  3
# 7                  4
# 8                  1
# 9                  1
# 10                 6
# 11                 5
# 12                 7
# 13                12
# 14                21
# 15                10
# 16                14
# 17                17
# 18                20
# 19                11
# 20                11
# 21                11
# 22                 9
# 23                 4
# 24                12
# 25                10
# 26                 7
# 27                20
# 28                34
# 29                55
# 30                88
# 31               122
# 32               366
# 33               691
# 34                 6
# 41                 1
# 42                 1
# 43                 2
# 44                 3
# 45                 3
# 47                 3
# 48                 1
# 49                 1
# 51                 2
# 52                 4

# %%
print(f'Mean tweets per month: { tweets_pmonth["tweets"].mean() }')
print(f'Median tweets per month: { tweets_pmonth["tweets"].median() }')
tweets_pmonth
# Out:
# Mean tweets per month: 147.27272727272728
# Median tweets per month: 28.0
#        tweets
# month
# 1          17
# 2          12
# 3          28
# 4          64
# 5          56
# 6          37
# 7         200
# 8        1185
# 10          7
# 11          7
# 12          7

# %% [markdown]
# # Free EDA
#
# Now that we got that out of the way, I will explore this data to try to find some interesting data on the user profiles
#
# Let us start with a Correlation Grid

# %%
plot = sns.PairGrid(main_df.drop(['day','month','week_of_year'],axis=1))
plot.map(sns.scatterplot)

# %% [markdown]
# ## Likes, Replies and Retweets
#
# We have already seen that there is little to no correlation between these as of how they are now. The closest we have is between Likes and Retweets which make sense
#
# Now let´s look at the distribution

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['likes'], kde=False)
fig.suptitle('Likes Distribution', fontsize=20)
plt.xlabel('Likes per Tweet', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# D:\Users\iuryck\anaconda3\envs\AnalyzeData\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['retweets'], kde=False)
fig.suptitle('Retweets Distribution', fontsize=20)
plt.xlabel('Retweets per Tweet', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
fig = plt.figure(figsize=(10,10))
sns.distplot(x=main_df['replies'], kde=False)
fig.suptitle('Replies Distribution', fontsize=20)
plt.xlabel('Replies per Tweet', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# As we can see the huge majority of tweets do no get millions of interactions.
#
# This makes our huge influencer/famous/viral tweets the **Outliers** of our data
#
# We can easily get the top 1% of tweets by using the [*3 sigma rule*](https://en.wikipedia.org/wiki/68–95–99.7_rule)

# %% [markdown]
# - These are the top of the top tweets by Likes

# %%
series = main_df['likes']


mu  = series.mean()
std = series.std()

#Gets all the data that is 3 standard deviations far from the mean
like_outliers = main_df[main_df['likes'] - mu > 3*std]
like_outliers
# Out:
#                                          date     likes    replies  retweets  \
# 1559669129535176710 2022-08-16 22:31:12+00:00  290000.0      9.840   41200.0
# 1557436132945707008 2022-08-10 18:38:04+00:00  505500.0  10100.000   27100.0
# 1553808180332969985 2022-07-31 18:21:53+00:00  776700.0  18800.000   43800.0
# 1553390665643573251 2022-07-30 14:42:49+00:00  533600.0  10200.000   34000.0
# 1552025605406851072 2022-07-26 20:18:34+00:00  293800.0      8.085   15900.0
# 1512160805634166784 2022-04-07 20:10:05+00:00  255300.0      4.939   13600.0
# 1510607454505209861 2022-04-03 13:17:37+00:00  422800.0      6.546   21700.0
# 1509106128340373510 2022-03-30 09:51:53+00:00  322300.0      5.120   19000.0
# 1507758300716277762 2022-03-26 16:36:06+00:00  386000.0      5.218   18700.0
# 1507129927598067714 2022-03-24 22:59:10+00:00  190000.0      3.553   14500.0
# 1559691922725281800 2022-08-17 00:01:46+00:00  437200.0  32800.000  117000.0
# 1558636751370928128 2022-08-14 02:08:54+00:00  230600.0  10000.000   22700.0
# 1559668535105794048 2022-08-16 22:28:50+00:00  185300.0      4.950   33300.0
# 1554219412181266433 2022-08-01 21:35:58+00:00  243900.0      4.014   35900.0
# 1553874059057926149 2022-07-31 22:43:39+00:00  230500.0      3.727   31900.0
# 1553070519725051911 2022-07-29 17:30:41+00:00  248000.0      3.510   34000.0
# 1528188268491194373 2022-05-22 01:37:30+00:00  397800.0      7.399   72100.0
# 1522290648790970368 2022-05-05 19:02:28+00:00  250900.0  11200.000   56200.0
# 1521414994075611136 2022-05-03 09:02:55+00:00  243400.0      5.320   36800.0
# 1521233317806309377 2022-05-02 21:01:00+00:00  334900.0  13900.000   72600.0
# 1519865588482330624 2022-04-29 02:26:08+00:00  656000.0  25100.000  176800.0
# 1518994867539505153 2022-04-26 16:46:12+00:00  390300.0      9.580   84700.0
# 1558601592877768704 2022-08-13 23:49:11+00:00  356300.0      5.794   24500.0
# 1518028875493777408 2022-04-24 00:47:42+00:00  309600.0      3.019   14600.0
# 1540382753677627393 2022-06-24 17:14:02+00:00  823100.0  11000.000  149400.0
# 1540183720845533185 2022-06-24 04:03:08+00:00  271200.0      9.218   73900.0
# 1529295926057123841 2022-05-25 02:58:56+00:00  375500.0      4.211   55100.0
# 1432029787107774465 2021-08-29 17:18:01+00:00  246200.0      9.864   51100.0
# 1429827296060391432 2021-08-23 15:26:06+00:00  196600.0  12300.000   40700.0
# 1423645698868891648 2021-08-06 14:02:39+00:00  354300.0  11900.000  102600.0
# 1423645701075046401 2021-08-06 14:02:39+00:00  192200.0      3.152   28600.0
# 1423318726749802496 2021-08-05 16:23:23+00:00  368500.0  25900.000   69100.0
# 1520933752364486657 2022-05-02 01:10:38+00:00  247200.0      1.982   19800.0
#
#                                 user date_joined    followers  day  month  \
# 1559669129535176710      BarackObama  2007-03-01  132500000.0   16      8
# 1557436132945707008        Cristiano  2010-06-01  102800000.0   10      8
# 1553808180332969985        Cristiano  2010-06-01  102800000.0   31      7
# 1553390665643573251        Cristiano  2010-06-01  102800000.0   30      7
# 1552025605406851072        Cristiano  2010-06-01  102800000.0   26      7
# 1512160805634166784        Cristiano  2010-06-01  102800000.0    7      4
# 1510607454505209861        Cristiano  2010-06-01  102800000.0    3      4
# 1509106128340373510        Cristiano  2010-06-01  102800000.0   30      3
# 1507758300716277762        Cristiano  2010-06-01  102800000.0   26      3
# 1507129927598067714        Cristiano  2010-06-01  102800000.0   24      3
# 1559691922725281800         elonmusk  2009-06-01  103300000.0   17      8
# 1558636751370928128         elonmusk  2009-06-01  103300000.0   14      8
# 1559668535105794048     Harry_Styles  2010-08-01   38100000.0   16      8
# 1554219412181266433     Harry_Styles  2010-08-01   38100000.0    1      8
# 1553874059057926149     Harry_Styles  2010-08-01   38100000.0   31      7
# 1553070519725051911     Harry_Styles  2010-08-01   38100000.0   29      7
# 1528188268491194373     Harry_Styles  2010-08-01   38100000.0   22      5
# 1522290648790970368     Harry_Styles  2010-08-01   38100000.0    5      5
# 1521414994075611136     Harry_Styles  2010-08-01   38100000.0    3      5
# 1521233317806309377     Harry_Styles  2010-08-01   38100000.0    2      5
# 1519865588482330624     Harry_Styles  2010-08-01   38100000.0   29      4
# 1518994867539505153     Harry_Styles  2010-08-01   38100000.0   26      4
# 1558601592877768704         neymarjr  2010-06-01   57600000.0   13      8
# 1518028875493777408         neymarjr  2010-06-01   57600000.0   24      4
# 1540382753677627393    taylorswift13  2008-12-01   90800000.0   24      6
# 1540183720845533185    taylorswift13  2008-12-01   90800000.0   24      6
# 1529295926057123841    taylorswift13  2008-12-01   90800000.0   25      5
# 1432029787107774465    taylorswift13  2008-12-01   90800000.0   29      8
# 1429827296060391432    taylorswift13  2008-12-01   90800000.0   23      8
# 1423645698868891648    taylorswift13  2008-12-01   90800000.0    6      8
# 1423645701075046401    taylorswift13  2008-12-01   90800000.0    6      8
# 1423318726749802496    taylorswift13  2008-12-01   90800000.0    5      8
# 1520933752364486657  unidadeAbsoluta  2020-05-01     131300.0    2      5
#
#                      week_of_year
# 1559669129535176710            33
# 1557436132945707008            32
# 1553808180332969985            30
# 1553390665643573251            30
# 1552025605406851072            30
# 1512160805634166784            14
# 1510607454505209861            13
# 1509106128340373510            13
# 1507758300716277762            12
# 1507129927598067714            12
# 1559691922725281800            33
# 1558636751370928128            32
# 1559668535105794048            33
# 1554219412181266433            31
# 1553874059057926149            30
# 1553070519725051911            30
# 1528188268491194373            20
# 1522290648790970368            18
# 1521414994075611136            18
# 1521233317806309377            18
# 1519865588482330624            17
# 1518994867539505153            17
# 1558601592877768704            32
# 1518028875493777408            16
# 1540382753677627393            25
# 1540183720845533185            25
# 1529295926057123841            21
# 1432029787107774465            34
# 1429827296060391432            34
# 1423645698868891648            31
# 1423645701075046401            31
# 1423318726749802496            31
# 1520933752364486657            18

# %% [markdown]
# - These are the top of the top tweets by Replies

# %%
series = main_df['replies']


mu  = series.mean()
std = series.std()

#Gets all the data that is 3 standard deviations far from the mean
replies_outliers = main_df[series - mu > 3*std]
replies_outliers
# Out:
#                                          date     likes  replies  retweets  \
# 1557436132945707008 2022-08-10 18:38:04+00:00  505500.0  10100.0   27100.0
# 1553808180332969985 2022-07-31 18:21:53+00:00  776700.0  18800.0   43800.0
# 1553390665643573251 2022-07-30 14:42:49+00:00  533600.0  10200.0   34000.0
# 1559690651687608321 2022-08-16 23:56:43+00:00  171500.0  13900.0   13700.0
# 1559691922725281800 2022-08-17 00:01:46+00:00  437200.0  32800.0  117000.0
# 1558636751370928128 2022-08-14 02:08:54+00:00  230600.0  10000.0   22700.0
# 1522290648790970368 2022-05-05 19:02:28+00:00  250900.0  11200.0   56200.0
# 1521233317806309377 2022-05-02 21:01:00+00:00  334900.0  13900.0   72600.0
# 1519865588482330624 2022-04-29 02:26:08+00:00  656000.0  25100.0  176800.0
# 1540382753677627393 2022-06-24 17:14:02+00:00  823100.0  11000.0  149400.0
# 1429827296060391432 2021-08-23 15:26:06+00:00  196600.0  12300.0   40700.0
# 1423645698868891648 2021-08-06 14:02:39+00:00  354300.0  11900.0  102600.0
# 1423318726749802496 2021-08-05 16:23:23+00:00  368500.0  25900.0   69100.0
#
#                               user date_joined    followers  day  month  \
# 1557436132945707008      Cristiano  2010-06-01  102800000.0   10      8
# 1553808180332969985      Cristiano  2010-06-01  102800000.0   31      7
# 1553390665643573251      Cristiano  2010-06-01  102800000.0   30      7
# 1559690651687608321       elonmusk  2009-06-01  103300000.0   16      8
# 1559691922725281800       elonmusk  2009-06-01  103300000.0   17      8
# 1558636751370928128       elonmusk  2009-06-01  103300000.0   14      8
# 1522290648790970368   Harry_Styles  2010-08-01   38100000.0    5      5
# 1521233317806309377   Harry_Styles  2010-08-01   38100000.0    2      5
# 1519865588482330624   Harry_Styles  2010-08-01   38100000.0   29      4
# 1540382753677627393  taylorswift13  2008-12-01   90800000.0   24      6
# 1429827296060391432  taylorswift13  2008-12-01   90800000.0   23      8
# 1423645698868891648  taylorswift13  2008-12-01   90800000.0    6      8
# 1423318726749802496  taylorswift13  2008-12-01   90800000.0    5      8
#
#                      week_of_year
# 1557436132945707008            32
# 1553808180332969985            30
# 1553390665643573251            30
# 1559690651687608321            33
# 1559691922725281800            33
# 1558636751370928128            32
# 1522290648790970368            18
# 1521233317806309377            18
# 1519865588482330624            17
# 1540382753677627393            25
# 1429827296060391432            34
# 1423645698868891648            31
# 1423318726749802496            31

# %% [markdown]
# - And the top of the top tweets by Retweets

# %%
series = main_df['retweets']


mu  = series.mean()
std = series.std()

#Gets all the data that is 3 standard deviations far from the mean
retweets_outliers = main_df[series - mu > 3*std]
retweets_outliers
# Out:
#                                          date     likes    replies  retweets  \
# 1559669129535176710 2022-08-16 22:31:12+00:00  290000.0      9.840   41200.0
# 1553808180332969985 2022-07-31 18:21:53+00:00  776700.0  18800.000   43800.0
# 1553390665643573251 2022-07-30 14:42:49+00:00  533600.0  10200.000   34000.0
# 1559691922725281800 2022-08-17 00:01:46+00:00  437200.0  32800.000  117000.0
# 1153669692273451008 2019-07-23 14:14:23+00:00   96800.0      4.953   35200.0
# 1559668535105794048 2022-08-16 22:28:50+00:00  185300.0      4.950   33300.0
# 1554219412181266433 2022-08-01 21:35:58+00:00  243900.0      4.014   35900.0
# 1553874059057926149 2022-07-31 22:43:39+00:00  230500.0      3.727   31900.0
# 1553070519725051911 2022-07-29 17:30:41+00:00  248000.0      3.510   34000.0
# 1528188268491194373 2022-05-22 01:37:30+00:00  397800.0      7.399   72100.0
# 1522290648790970368 2022-05-05 19:02:28+00:00  250900.0  11200.000   56200.0
# 1521414994075611136 2022-05-03 09:02:55+00:00  243400.0      5.320   36800.0
# 1521233317806309377 2022-05-02 21:01:00+00:00  334900.0  13900.000   72600.0
# 1519865588482330624 2022-04-29 02:26:08+00:00  656000.0  25100.000  176800.0
# 1518994867539505153 2022-04-26 16:46:12+00:00  390300.0      9.580   84700.0
# 1540382753677627393 2022-06-24 17:14:02+00:00  823100.0  11000.000  149400.0
# 1540183720845533185 2022-06-24 04:03:08+00:00  271200.0      9.218   73900.0
# 1529295926057123841 2022-05-25 02:58:56+00:00  375500.0      4.211   55100.0
# 1432029787107774465 2021-08-29 17:18:01+00:00  246200.0      9.864   51100.0
# 1429827296060391432 2021-08-23 15:26:06+00:00  196600.0  12300.000   40700.0
# 1423645698868891648 2021-08-06 14:02:39+00:00  354300.0  11900.000  102600.0
# 1423318726749802496 2021-08-05 16:23:23+00:00  368500.0  25900.000   69100.0
# 1519168496839626752 2022-04-27 04:16:09+00:00  114200.0    793.000   33900.0
#
#                                user date_joined    followers  day  month  \
# 1559669129535176710     BarackObama  2007-03-01  132500000.0   16      8
# 1553808180332969985       Cristiano  2010-06-01  102800000.0   31      7
# 1553390665643573251       Cristiano  2010-06-01  102800000.0   30      7
# 1559691922725281800        elonmusk  2009-06-01  103300000.0   17      8
# 1153669692273451008      filipeluis  2010-10-01    1700000.0   23      7
# 1559668535105794048    Harry_Styles  2010-08-01   38100000.0   16      8
# 1554219412181266433    Harry_Styles  2010-08-01   38100000.0    1      8
# 1553874059057926149    Harry_Styles  2010-08-01   38100000.0   31      7
# 1553070519725051911    Harry_Styles  2010-08-01   38100000.0   29      7
# 1528188268491194373    Harry_Styles  2010-08-01   38100000.0   22      5
# 1522290648790970368    Harry_Styles  2010-08-01   38100000.0    5      5
# 1521414994075611136    Harry_Styles  2010-08-01   38100000.0    3      5
# 1521233317806309377    Harry_Styles  2010-08-01   38100000.0    2      5
# 1519865588482330624    Harry_Styles  2010-08-01   38100000.0   29      4
# 1518994867539505153    Harry_Styles  2010-08-01   38100000.0   26      4
# 1540382753677627393   taylorswift13  2008-12-01   90800000.0   24      6
# 1540183720845533185   taylorswift13  2008-12-01   90800000.0   24      6
# 1529295926057123841   taylorswift13  2008-12-01   90800000.0   25      5
# 1432029787107774465   taylorswift13  2008-12-01   90800000.0   29      8
# 1429827296060391432   taylorswift13  2008-12-01   90800000.0   23      8
# 1423645698868891648   taylorswift13  2008-12-01   90800000.0    6      8
# 1423318726749802496   taylorswift13  2008-12-01   90800000.0    5      8
# 1519168496839626752  thomassantanas  2017-05-01    1400000.0   27      4
#
#                      week_of_year
# 1559669129535176710            33
# 1553808180332969985            30
# 1553390665643573251            30
# 1559691922725281800            33
# 1153669692273451008            30
# 1559668535105794048            33
# 1554219412181266433            31
# 1553874059057926149            30
# 1553070519725051911            30
# 1528188268491194373            20
# 1522290648790970368            18
# 1521414994075611136            18
# 1521233317806309377            18
# 1519865588482330624            17
# 1518994867539505153            17
# 1540382753677627393            25
# 1540183720845533185            25
# 1529295926057123841            21
# 1432029787107774465            34
# 1429827296060391432            34
# 1423645698868891648            31
# 1423318726749802496            31
# 1519168496839626752            17

# %% [markdown]
# This is some nice data, but maybe it is *too* much. We can barely call this a dataset, it's so few tweets.
#
# We can change this by shrinking our outlier range, our data is super skewed so maybe 1 or 2 standard deviations is enough.
#
# An maybe people like Barack Obama and Taylor Swift are just on a whole different level, let´s exclude them from our analysis as *true outliers*.

# %%
series = main_df['likes']


mu  = series.mean()
std = series.std()

#Gets all the data that is between 1 and 3 standard deviations far from the mean
like_outliers = main_df[(series - mu > 1*std) & (series - mu < 3*std)]
like_outliers
# Out:
#                                          date     likes    replies   retweets  \
# 1543958093431726080 2022-07-04 14:01:09+00:00  182100.0      3.651      6.403
# 1547412864645976064 2022-07-14 02:49:11+00:00   73400.0      1.620      9.068
# 1518698766009782272 2022-04-25 21:09:36+00:00   72700.0    799.000  20200.000
# 1507643527760527360 2022-03-26 09:00:02+00:00   75300.0      2.036      4.887
# 1559690651687608321 2022-08-16 23:56:43+00:00  171500.0  13900.000  13700.000
# 1558867758368133122 2022-08-14 17:26:50+00:00  148900.0      8.841  10600.000
# 1558303186326265857 2022-08-13 04:03:26+00:00   88600.0      5.245      6.881
# 1555726190450659328 2022-08-06 01:23:22+00:00  149100.0      6.849  10200.000
# 1555794448826900480 2022-08-06 05:54:36+00:00   90300.0      1.981      4.456
# 1555799183067684866 2022-08-06 06:13:25+00:00   86000.0      4.127      3.845
# 1153669692273451008 2019-07-23 14:14:23+00:00   96800.0      4.953  35200.000
# 1557206400190873603 2022-08-10 03:25:11+00:00   93700.0      2.926  22200.000
# 1517921347980218368 2022-04-23 17:40:25+00:00   79500.0      1.211      8.451
# 1558199098112720896 2022-08-12 21:09:49+00:00   90800.0      3.570  17000.000
# 1559259903889481729 2022-08-15 19:25:05+00:00   90100.0      1.486  12100.000
# 1555373537837326339 2022-08-05 02:02:03+00:00  108000.0      5.880  15000.000
# 1559133045982126082 2022-08-15 11:01:00+00:00  114100.0    157.000  13400.000
# 1558604728338202637 2022-08-14 00:01:39+00:00  103200.0    368.000      7.127
# 1558504708905508866 2022-08-13 17:24:12+00:00   72000.0    994.000      3.568
# 1517522776285921280 2022-04-22 15:16:38+00:00  133800.0      2.992  12100.000
# 1540183725027229703 2022-06-24 04:03:09+00:00  127700.0      1.856  20000.000
# 1431302774277480454 2021-08-27 17:09:08+00:00  142900.0      4.823  20000.000
# 1519168496839626752 2022-04-27 04:16:09+00:00  114200.0    793.000  33900.000
# 1492883353703493638 2022-02-13 15:28:22+00:00  137700.0      1.425  11300.000
# 1449788053707542535 2021-10-17 17:23:02+00:00  109600.0    322.000  12700.000
# 1559566995493982210 2022-08-16 15:45:21+00:00   91700.0    214.000      2.228
# 1558152912668426242 2022-08-12 18:06:18+00:00  104700.0      1.475      6.423
# 1544691339769569280 2022-07-06 14:34:49+00:00   83300.0    783.000      4.351
# 1543205822045593600 2022-07-02 12:11:54+00:00  173700.0    915.000      4.909
# 1550616818376646659 2022-07-22 23:00:33+00:00   73100.0    204.000      2.383
#
#                                 user date_joined    followers  day  month  \
# 1543958093431726080      BarackObama  2007-03-01  132500000.0    4      7
# 1547412864645976064    Brunohenrique  2016-06-01    1800000.0   14      7
# 1518698766009782272      cabelinhomc  2014-02-01    1600000.0   25      4
# 1507643527760527360        Cristiano  2010-06-01  102800000.0   26      3
# 1559690651687608321         elonmusk  2009-06-01  103300000.0   16      8
# 1558867758368133122         elonmusk  2009-06-01  103300000.0   14      8
# 1558303186326265857         elonmusk  2009-06-01  103300000.0   13      8
# 1555726190450659328         elonmusk  2009-06-01  103300000.0    6      8
# 1555794448826900480         elonmusk  2009-06-01  103300000.0    6      8
# 1555799183067684866         elonmusk  2009-06-01  103300000.0    6      8
# 1153669692273451008       filipeluis  2010-10-01    1700000.0   23      7
# 1557206400190873603          gabigol  2010-09-01    4100000.0   10      8
# 1517921347980218368      GiorgiandeA  2012-08-01    1400000.0   23      4
# 1558199098112720896    jairbolsonaro  2010-03-01    8600000.0   12      8
# 1559259903889481729      macacosfoda  2020-07-01     147400.0   15      8
# 1555373537837326339      macacosfoda  2020-07-01     147400.0    5      8
# 1559133045982126082    maiconkusterk  2015-03-01    1900000.0   15      8
# 1558604728338202637    maiconkusterk  2015-03-01    1900000.0   14      8
# 1558504708905508866         neymarjr  2010-06-01   57600000.0   13      8
# 1517522776285921280         neymarjr  2010-06-01   57600000.0   22      4
# 1540183725027229703    taylorswift13  2008-12-01   90800000.0   24      6
# 1431302774277480454    taylorswift13  2008-12-01   90800000.0   27      8
# 1519168496839626752   thomassantanas  2017-05-01    1400000.0   27      4
# 1492883353703493638  unidadeAbsoluta  2020-05-01     131300.0   13      2
# 1449788053707542535  unidadeAbsoluta  2020-05-01     131300.0   17     10
# 1559566995493982210           vinijr  2014-02-01    3900000.0   16      8
# 1558152912668426242           vinijr  2014-02-01    3900000.0   12      8
# 1544691339769569280           vinijr  2014-02-01    3900000.0    6      7
# 1543205822045593600           vinijr  2014-02-01    3900000.0    2      7
# 1550616818376646659      xamaoficial  2016-02-01    4400000.0   22      7
#
#                      week_of_year
# 1543958093431726080            27
# 1547412864645976064            28
# 1518698766009782272            17
# 1507643527760527360            12
# 1559690651687608321            33
# 1558867758368133122            32
# 1558303186326265857            32
# 1555726190450659328            31
# 1555794448826900480            31
# 1555799183067684866            31
# 1153669692273451008            30
# 1557206400190873603            32
# 1517921347980218368            16
# 1558199098112720896            32
# 1559259903889481729            33
# 1555373537837326339            31
# 1559133045982126082            33
# 1558604728338202637            32
# 1558504708905508866            32
# 1517522776285921280            16
# 1540183725027229703            25
# 1431302774277480454            34
# 1519168496839626752            17
# 1492883353703493638             6
# 1449788053707542535            41
# 1559566995493982210            33
# 1558152912668426242            32
# 1544691339769569280            27
# 1543205822045593600            26
# 1550616818376646659            29

# %% [markdown]
# That looks a bit better
#
# But now let´s try to define a score of sorts between user profiles.

# %% [markdown]
# ## Scoring Users on Likes Retweets and Replies
#
# What we will be doing is sum up all the data of each individual user per tweet. So in other words, for each tweet a user has, we will sum the likes, for example, of that user, that way we can make a list of top users based on some profiles.
#
# Some profiles we can derive from this data is:
#
# - Viral: Retweets are a good way to define how viral a tweet is, anyone can agree on that. Now if we made a score for how much retweets a profile gets for all their tweets we can determine how much of a viral profile they are, in other words, how much reach they have. Profiles that fit here are Meme Pages for example
#
#
# - Engaging: These are profiles that people comment/reply alot, people come to these profiles to discuss, maybe it is even a polemical profile. But what matters here is that we want to see how much a profile attracts user attention with comments and discussion. People with loyal and engaging fan bases might fit into this category, as well as controversial people who attract criticism and hate.
#
#
# - Popularity(?): Likes are the hard one, they can mean so many things, maybe it's a famous artist, maybe it's a humor page, or someone that has very popular and likeable opinions. Either way at least we can tell one thing, a person that has millions and millions of likes is very popular, people like Barack Obama and Taylor Swift as seen before.
#
# So we will try to transform the data in a way that we can make try to score it into these 3 categories.

# %% [markdown]
# Below we will be crunching down the data to better see the distribution of data

# %%
#Crunch down the data with cubic root
main_df['likes_norm'] = main_df['likes']**(1/3)


fig = plt.figure(figsize=(10,10))
sns.histplot(x=main_df['likes_norm'], kde=False)
fig.suptitle('Likes Normalized Distribution', fontsize=20)
plt.xlabel('Likes Normalized', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
#Crunch down the data with cubic root
main_df['replies_norm'] = (main_df['replies'])**(1/3)

fig = plt.figure(figsize=(10,10))
sns.histplot(x=main_df['replies_norm'], kde=False)
fig.suptitle('Replies Normalized Distribution', fontsize=20)
plt.xlabel('Replies Normalized', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
#Crunch down the data with cubic root
main_df['retweets_norm'] = main_df['retweets']**(1/3)

fig = plt.figure(figsize=(10,10))
sns.histplot(x=main_df['retweets_norm'], kde=False)
fig.suptitle('Retweets Normalized Distribution', fontsize=20)
plt.xlabel('Retweets Normalized', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# If a product is retweeted, and gets alot of likes, that is good. But if a product is retweeted and gets alot of replies, then the product might be in discussion and it will bring more people in, and that is free advertisement. With this in mind we will define features in which we evaluate a users tweet value by how many likes they get per retweet and how many replies they get per retweet

# %%
#Adding ones to our 0 values so we dont get NaNs
main_df.loc[main_df.retweets==0, 'retweets'] = 1

#Get how many replies per tweet, then crunch data
main_df['retweet_engagement'] = (main_df['replies']/main_df['retweets'])**(1/3)

fig = plt.figure(figsize=(10,10))
sns.histplot(x=main_df['retweet_engagement'], kde=False)
fig.suptitle('Replies per Retweet Distribution', fontsize=20)
plt.xlabel('Replies per Retweet Normalized', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %%
#Get how many replies per tweet, then crunch data
main_df['retweet_likes'] = (main_df['likes']/main_df['retweets'])**(1/3)

fig = plt.figure(figsize=(10,10))
sns.histplot(x=main_df['retweet_likes'], kde=False)
fig.suptitle('Likes per Retweet Distribution', fontsize=20)
plt.xlabel('Likes per Retweet Normalized', fontsize=18)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Telling from Distributions

# %% [markdown]
# From the distributions we can see that it is a very select few tweets that actually get a lot of exposure. So already we are somewhat limited in our analysis to find marketing valuable users/tweets. Not to mention we are limited by the amount of tweets we have and their timespan.
#
# But we can still find some interesting things. Let's create some variables that can show us some interesting things.

# %% [markdown]
# Here are the users that have gained the most amount of followers per day, on average, since they created their account. This might show us people that have a insane amount of growth in a short timespan.

# %%
main_df['account_active_days'] = [(dt.datetime.now() - c).days for c in main_df['date_joined']]
main_df['followers_p_active_days'] = main_df['followers']/main_df['account_active_days']
main_df.sort_values('followers_p_active_days', ascending=False)[['followers_p_active_days','user']].drop_duplicates().head(10)
# Out:
#                      followers_p_active_days            user
# 1544082823690297350             23455.478846     BarackObama
# 1507758300716277762             23044.160502       Cristiano
# 1558867758368133122             21404.890178        elonmusk
# 1423645701075046401             18130.990415   taylorswift13
# 1512107442099871755             12911.903161        neymarjr
# 1550255527632031744             10573.403823       KingJames
# 1518994867539505153              8659.090909    Harry_Styles
# 1553792716567445504              6007.480131     whindersson
# 1550228003015237633              5882.352941  luvadepedreiro
# 1559585843320442886              5119.214586   NetflixBrasil

# %% [markdown]
# Look at this user, a million followers in a few months! Certainly a viral user.

# %%
main_df[main_df['user']=='luvadepedreiro'][['user','date_joined','followers']].drop_duplicates()
# Out:
#                                user date_joined  followers
# 1559723641096572928  luvadepedreiro  2022-03-01  1000000.0

# %% [markdown]
# Now let´s sum up the data for evey profile page

# %%
users_scores = main_df[['likes', 'retweets','replies','user','retweet_engagement','retweet_likes']].groupby('user').sum()
users_scores.head(10)
# Out:
#                     likes   retweets   replies  retweet_engagement  \
# user
# Anitta         208003.791  11897.535  5614.919           36.937562
# Astronomiaum    24298.213   2688.160   430.000            7.249242
# BarackObama    593916.563  41229.727  2638.179           35.222519
# BlogdoJuca       1116.000     83.000    33.000           10.109576
# BoliviaMod        792.152    475.000    87.000           12.632092
# Brasileirao      3511.404    625.000   228.000            8.790663
# BruMarquezine     781.598    925.000   648.000            9.452732
# Brunohenrique  335106.422   2847.706  2881.908           29.304499
# CBF_Futebol      2542.438    534.000   267.000            8.959051
# CesarMenotti     1525.006    397.000   631.000           14.371034
#
#                retweet_likes
# user
# Anitta            119.521257
# Astronomiaum       24.641890
# BarackObama       146.590690
# BlogdoJuca         27.932175
# BoliviaMod         32.692219
# Brasileirao        22.733429
# BruMarquezine       6.089292
# Brunohenrique     157.966929
# CBF_Futebol        23.140233
# CesarMenotti       12.977171

# %% [markdown]
# Top 10 users with the most amount of Likes on their tweets

# %%
users_scores.sort_values('likes', ascending=False).head(10)[['likes']]
# Out:
#                        likes
# user
# Cristiano        3761300.000
# Harry_Styles     3181000.000
# taylorswift13    3098200.000
# elonmusk         1495800.000
# neymarjr          951316.486
# vinijr            710300.000
# BarackObama       593916.563
# unidadeAbsoluta   552132.011
# maiconkusterk     436609.814
# GiorgiandeA       407400.000

# %% [markdown]
# Top 10 users with the most amount of Replies on their tweets

# %%
users_scores.sort_values('replies', ascending=False).head(10)[['replies']]
# Out:
#                  replies
# user
# taylorswift13  61133.124
# elonmusk       56734.919
# Harry_Styles   50238.500
# Cristiano      39135.497
# Anitta          5614.919
# cellbit         4783.231
# neymarjr        4333.805
# vinijr          4220.475
# GiorgiandeA     4113.653
# KingJames       3563.118

# %% [markdown]
# Top 10 users with the most amount of Retweets on their tweets

# %%
users_scores.sort_values('retweets', ascending=False).head(10)[['retweets']]
# Out:
#                    retweets
# user
# Harry_Styles     634300.000
# taylorswift13    610500.000
# Cristiano        208304.887
# elonmusk         174222.141
# neymarjr          54127.445
# unidadeAbsoluta   45755.934
# BarackObama       41229.727
# macacosfoda       39620.151
# filipeluis        37922.777
# thomassantanas    34406.992

# %% [markdown]
# Notice how some users change and shift places, indicating a sort of profile. A user may not have many like on their tweets but have alot of retweets or replies. And with that they show up in the top 10 of one datasample and disappear in the other. Like the user cellbit that shows only in the top 10 users by replies. This might indicate some user activity that is really rallying people together (as a person that follows the user, I can confirm there is).
#
# Now a variable that might interest more in a marketing point of view are Retweets. If a user has a lot of retweets then they have alot of range, and we want to evaluate the quality of that range as well. Replies generate engagement and advertisement of said tweet, while Likes may represent popularity or likeability of the tweet. So we can try to evaluate a users reach by getting the likes and replies per retweet. This will also help us in profiling a user.
#
# Below are the top 10 profiles by replies per tweet. As we can see here, the user cellbit we talked about has yet again appeared in a data sample about engagement, this can indicate the user generates alot of engagement and discussion with their tweets. Notice also how some users will have more engagement per retweet, but less retweets than others. This might tell us that even though the user does not have the most retweets, they can make each one count.

# %%
users_scores.sort_values('retweet_engagement', ascending=False).head(10)[['retweets','retweet_engagement']]
# Out:
#                 retweets  retweet_engagement
# user
# KingJames        986.232           43.904910
# GiorgiandeA      625.060           42.802027
# cellbit         1469.180           42.094407
# gabigol        22228.850           41.934661
# vinijr          1473.705           40.114801
# Anitta         11897.535           36.937562
# BarackObama    41229.727           35.222519
# maiconkusterk  14542.588           31.002676
# FilipeRet       1634.726           30.264327
# matue30         1962.010           29.415383

# %% [markdown]
# Here we have the likes per retweet

# %%
users_scores.sort_values('retweet_likes', ascending=False).head(10)[['retweets','retweet_likes']]
# Out:
#                    retweets  retweet_likes
# user
# vinijr             1473.705     236.964072
# GiorgiandeA         625.060     212.591078
# gabigol           22228.850     205.711128
# KingJames           986.232     198.329530
# shitpostverdade     638.148     190.733376
# maiconkusterk     14542.588     162.973589
# Brunohenrique      2847.706     157.966929
# cellbit            1469.180     155.758866
# BarackObama       41229.727     146.590690
# elonmusk         174222.141     136.464227

# %% [markdown]
# # Conclusion
#
# Although the data in the current state is limiting, it has lots of potential. A lot here can be used as *trailing data* if we had more, which would show users trending and falling in the eyes of the public over time. Maybe even use Natural Language Processing to get Sentiment Analysis data and compare that to likes, retweets and replies. I hope I was able to explain the ideas and presentations made in this notebook clearly and that I was able to achieve the expectations to this test.
